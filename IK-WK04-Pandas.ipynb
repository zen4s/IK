# %%
#pandas --> datas
import pandas as pd

# %% [markdown]
# Subhra Ghosh (You): How much data (millions of row) can be processed by dataframes?
# Hannah Chen: The amount of data that can be processed by pandas DataFrames depends on the available system memory (RAM), data complexity, hardware, and efficiency of your code. Typically, pandas can handle datasets with millions of rows as long as they fit into memory. For larger datasets, consider techniques like chunking, streaming, or distributed computing frameworks. It's best to benchmark and monitor memory usage for your specific use case.
#
# Subhra Ghosh (You): Are all pandas dataframe happens in memory ?
# Hannah Chen: Yes, by default, pandas DataFrames are stored in memory.

# %%
pd.Series([11,22,33])
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
csv_url='https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv'

# %%
df_csv = pd.read_csv(csv_url)
#default "header = 0" that 1st row is a header

# %%
df_csv.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
excel_path = '/content/drive/MyDrive/Book1.xlsx'

# %%
df_sheet = pd.read_excel(excel_path, sheet_name=0) #sheet_name=0 is 1st tab

# %%
df_sheet.head(2)
# Out:
#         1      2       4      5
# 0     ddd     ff      gg     gg
# 1  asafsd  sddsf  sdfdsf  fdsfd

# %%
dataframe = pd.DataFrame()

# %%
#add columns one by one
dataframe['Name'] = ['Lilly','Emma']
dataframe['Age'] =[34,25]
dataframe['Edu'] = ['school','College']

# %%
dataframe
# Out:
#     Name  Age      Edu
# 0  Lilly   34   school
# 1   Emma   25  College

# %%
#Create data dictionary
data_dict = {'Name': ['Subh','Amy'],
        'Age': [29,44],
        'Edu': ['School','College'],
        'Sex': [1,1]
}

# %%
dataframe1 = pd.DataFrame(data_dict)
dataframe1
# Out:
#    Name  Age      Edu  Sex
# 0  Subh   29   School    1
# 1   Amy   44  College    1

# %%
## Get descriptive statistics for any numeric columns
dataframe1.describe()
# Out:
#              Age  Sex
# count   2.000000  2.0
# mean   36.500000  1.0
# std    10.606602  0.0
# min    29.000000  1.0
# 25%    32.750000  1.0
# 50%    36.500000  1.0
# 75%    40.250000  1.0
# max    44.000000  1.0

# %%
#Create data dictionary
datad_dict_2 = {'Name': ['Subh','Amy','Lilly','Emma'],
        'Age': [29,44,22,55],
        'Edu': ['School','College','Phd','College'],
        'Sex': [1,1,0,0]
}

# %%
df = pd.DataFrame(data_dict_2)
df
# Out:
#     Name  Age      Edu  Sex
# 0   Subh   29   School    1
# 1    Amy   44  College    1
# 2  Lilly   22      Phd    0
# 3   Emma   55  College    0

# %%
dataframe2 = df2 = pd.DataFrame(data_dict_2,index=['one','two','three','four'])
dataframe2
# Out:
#         Name  Age      Edu  Sex
# one     Subh   29   School    1
# two      Amy   44  College    1
# three  Lilly   22      Phd    0
# four    Emma   55  College    0

# %%
dataframe2.iloc[0]
# Out:
# Name      Subh
# Age         29
# Edu     School
# Sex          1
# Name: one, dtype: object

# %%
dataframe2.loc['one'] #same as dataframe2.iloc[0]
# Out:
# Name      Subh
# Age         29
# Edu     School
# Sex          1
# Name: one, dtype: object

# %%
df2.iloc[:2] #first two rows
# Out:
#      Name  Age      Edu  Sex
# one  Subh   29   School    1
# two   Amy   44  College    1

# %%
dataframe2.loc[0] #will give error as index 0 changed to one
#loc is label based syntax based
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2.iloc[:2,0-+] #first two columns
# Out:
# one    Subh
# two     Amy
# Name: Name, dtype: object

# %%
#three row & two colums
df2.iloc[:2,:3]
# Out:
#      Name  Age      Edu
# one  Subh   29   School
# two   Amy   44  College

# %%
#First Two Rows & Two Colums
df.iloc[:2,:2] # same as df.loc[:2,['Name','Age']]
# Out:
#    Name  Age
# 0  Subh   29
# 1   Amy   44

# %%
df.loc[:2,['Name','Age']]
# Out:
#     Name  Age
# 0   Subh   29
# 1    Amy   44
# 2  Lilly   22

# %%
df.iloc[:2,:3]
# Out:
#    Name  Age      Edu
# 0  Subh   29   School
# 1   Amy   44  College

# %%
df2['Name'] #returns a series
# Out:
# one       Subh
# two        Amy
# three    Lilly
# four      Emma
# Name: Name, dtype: object

# %%
df2[['Name']] #returns data table
# Out:
#         Name
# one     Subh
# two      Amy
# three  Lilly
# four    Emma

# %%
filter = df['Sex'] == 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[filter]
# Out:
#     Name  Age      Edu  Gender_Code
# 2  Lilly   22      Phd            0
# 3   Emma   55  College            0

# %%
df.rename(columns={'Sex':'Gender_Code'},inplace=True)
df
# Out:
#     Name  Age      Edu  Gender_Code
# 0   Subh   29   School            1
# 1    Amy   44  College            1
# 2  Lilly   22      Phd            0
# 3   Emma   55  College            0

# %%
filter = df['Gender_Code'] == 0
filter
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: Gender_Code, dtype: bool

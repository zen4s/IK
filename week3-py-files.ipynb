# %%
x = 5
def foo():
  # x = x + 1
  # UnboundLocalError: local variable 'x' referenced before assignment
  # Happens due x= assginement of x
  x + 1 # works as there is no assignment
  print("Inside foo", x)

foo()
print(x)
# Out:
# Inside foo 5
# 5

# %%
#Class def
class Car:
  # def drive():  --> No argumant
  # TypeError: Car.drive() takes 0 positional arguments but 1 was given
  # my_car.drive() --> Python always sent refrence to the method by default
   def drive(self):  #method drive for class Car, add self in argument to avoid zero argument error
       print("Drive the Car")


# Object / Instance
my_car = Car()
my_car.drive()
# Out:
# Drive the Car

# %%
# Demo constructor. Python automaticalls creates constructor
